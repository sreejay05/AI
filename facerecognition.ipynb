# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejay05/AI2/blob/master/facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = 'images.jpg'
im =cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces, confidences = cv.detect_face(im)
for face in faces:
  (startX,startY) = face[0],face[1]
  (endX,endY) =face[2],face[3]
  cv2.rectangle(im, (startX,startY), (endX,endY), (0,225,0), 2)
plt.imshow(im)
plt.show()

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 2.8MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=8ed318fca0b8844bde3c73051be7c7c4dd905526465ad9bfcda69153549b2830
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=65681391331868b255459f18617501b1290b58c1c9c93fc4e39bc00ab5a2ada8
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...
